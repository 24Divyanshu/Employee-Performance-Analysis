# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('Employee_Performance.xls')

# %%
df.head(10)
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32    Male           Marketing        Single            Sales
# 1  E1001006   47    Male           Marketing        Single            Sales
# 2  E1001007   40    Male       Life Sciences       Married            Sales
# 3  E1001009   41    Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60    Male           Marketing        Single            Sales
# 5  E1001011   27    Male       Life Sciences      Divorced      Development
# 6  E1001016   50    Male           Marketing       Married            Sales
# 7  E1001019   28  Female       Life Sciences        Single      Development
# 8  E1001020   36  Female       Life Sciences       Married      Development
# 9  E1001021   38  Female       Life Sciences        Single      Development
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# ...

# %%
df.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      725
# Female    475
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar',ylabel='No.of gender')
# Out:
# <Axes: xlabel='Gender', ylabel='No.of gender'>

# %%
df['EducationBackground'].value_counts()
# Out:
# EducationBackground
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: count, dtype: int64

# %%
df['EducationBackground'].value_counts().plot(kind='bar',title='Education Background')
# Out:
# <Axes: title={'center': 'Education Background'}, xlabel='EducationBackground'>

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     548
# Single      384
# Divorced    268
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts().plot(kind='pie',autopct='%1.1f%%', title='Marital Status')
# Out:
# <Axes: title={'center': 'Marital Status'}, ylabel='count'>

# %%
df['EmpDepartment'].value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %%
df['EmpDepartment'].value_counts().plot(kind='bar',ylabel='No.of people',title='Employees distribution')
# Out:
# <Axes: title={'center': 'Employees distribution'}, xlabel='EmpDepartment', ylabel='No.of people'>

# %%
df['EmpJobRole'].value_counts()
# Out:
# EmpJobRole
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: count, dtype: int64

# %%
df['EmpJobRole'].value_counts().plot(kind='bar',ylabel='No.of person',title='Job Role Distribution')
# Out:
# <Axes: title={'center': 'Job Role Distribution'}, xlabel='EmpJobRole', ylabel='No.of person'>

# %%
df['BusinessTravelFrequency'].value_counts()
# Out:
# BusinessTravelFrequency
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: count, dtype: int64

# %%
df['BusinessTravelFrequency'].value_counts().plot(kind='pie',title='Buisness Travel Distribution',autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Buisness Travel Distribution'}, ylabel='count'>

# %%
df['OverTime'].value_counts()
# Out:
# OverTime
# No     847
# Yes    353
# Name: count, dtype: int64

# %%
df['OverTime'].value_counts().plot(kind='pie',title='Overtime Distribution',autopct='%1.1f%%',legend='true')
# Out:
# <Axes: title={'center': 'Overtime Distribution'}, ylabel='count'>

# %%
df['Age'].value_counts()
# Out:
# Age
# 34    71
# 35    64
# 36    60
# 31    57
# 29    51
# 38    48
# 32    46
# 40    46
# 33    46
# 27    43
# 30    42
# 37    41
# 28    39
# 45    36
# 42    36
# 26    33
# 41    32
# 39    31
# 44    30
# 50    28
# 43    26
# 46    24
# 25    24
# 49    21
# 24    20
# 47    20
# 55    17
# 54    16
# 48    16
# 52    15
# 53    15
# 22    15
# 51    14
# 56    11
# 21    11
# 58    11
# 23     9
# 19     8
# 18     8
# 20     6
# 59     6
# 57     4
# 60     3
# Name: count, dtype: int64

# %%
df['Age'].value_counts().plot(kind='bar',figsize=(10,7),title='Age Distribution',ylabel='No.of people')
plt.show()

# %%
df['ExperienceYearsAtThisCompany'].value_counts().plot(kind='bar',figsize=(15,8),ylabel='No.of people',title='Expirence year in company')
# Out:
# <Axes: title={'center': 'Expirence year in company'}, xlabel='ExperienceYearsAtThisCompany', ylabel='No.of people'>

# %%
df['DistanceFromHome'].value_counts().plot(kind='bar',ylabel='no.of emp',title='Distance from home')
# Out:
# <Axes: title={'center': 'Distance from home'}, xlabel='DistanceFromHome', ylabel='no.of emp'>

# %%
sns.lineplot(x='Age',y='TotalWorkExperienceInYears',data=df)

plt.title('Relation b/w Age & TotalWorkExperienceInYears')
plt.show()

# %%
sns.lineplot(x='ExperienceYearsAtThisCompany',y='TotalWorkExperienceInYears',data=df)
plt.title('Relation b/w ExperienceYearsAtThisCompany & TotalWorkExperienceInYears')
plt.show()

# %%
sns.lineplot(x='EmpHourlyRate',y='YearsWithCurrManager',data=df)
plt.title('Relation b/w EmpHourlyRate & YearsWithCurrManager ')
# Out:
# Text(0.5, 1.0, 'Relation b/w EmpHourlyRate & YearsWithCurrManager ')

# %%
sns.lineplot(x='DistanceFromHome',y='EmpLastSalaryHikePercent',data=df)
plt.title('Relation b/w DistanceFromHome & EmpLastSalaryHikePercent')
# Out:
# Text(0.5, 1.0, 'Relation b/w DistanceFromHome & EmpLastSalaryHikePercent')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='EmpJobRole',hue=df.PerformanceRating,data=df)
plt.xticks(rotation='vertical')
plt.xlabel('EmpJobRole',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()

# %%
sns.countplot(x='Gender',hue=df.PerformanceRating,data=df)
plt.ylabel='Performance Rating'
plt.show()
